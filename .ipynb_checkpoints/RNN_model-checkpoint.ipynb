# %%
import pandas as pd
import seaborn as sns
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pickle
import keras

# %%
def create_target_label(df):
    
    """
    Function takes as input the data-frame and creates a binary variable = 1 if taking this trade would have increased the 
    score, and 0 otherwise.
    """
    
    df['y'] = 0
    mask = df[['resp','resp_1','resp_2','resp_3','resp_4']].sum(axis = 1) >= 0
    df.loc[mask,'y'] = 1
    
    return df

# %%
def load_data(nrows):
    
    df = pd.read_csv('C:/Users/mathias.buxhoeveden/Desktop/kagglepm/Data/train.csv', nrows= nrows)

# %%
df = pd.read_csv('C:/Users/mathias.buxhoeveden/Desktop/kagglepm/Data/train.csv', nrows= 100000)

# %%
#Flag trades that will increase the target-score!

df = create_target_label(df = df)

# %%
df.
# Out:
#        date     weight    resp_1    resp_2    resp_3    resp_4      resp  \
# 0         0   0.000000  0.009916  0.014079  0.008773  0.001390  0.006270
# 1         0  16.673515 -0.002828 -0.003226 -0.007319 -0.011114 -0.009792
# 2         0   0.000000  0.025134  0.027607  0.033406  0.034380  0.023970
# 3         0   0.000000 -0.004730 -0.003273 -0.000461 -0.000476 -0.003200
# 4         0   0.138531  0.001252  0.002165 -0.001215 -0.006219 -0.002604
# ...     ...        ...       ...       ...       ...       ...       ...
# 99995    16   0.000000 -0.000567 -0.001869  0.000209  0.005757  0.002378
# 99996    16   7.244412 -0.005087 -0.003462  0.003404 -0.002871 -0.007983
# 99997    16   0.742093 -0.004017 -0.005074 -0.003260  0.002065  0.000325
# 99998    16   0.223989  0.009427  0.014389  0.045104  0.055153  0.038939
# 99999    16   2.780260  0.003875  0.008955  0.014597  0.023805  0.022352
#
#        feature_0  feature_1  feature_2  ...  feature_122  feature_123  \
# 0              1  -1.872746  -2.191242  ...     1.168391     8.313583
# 1             -1  -1.349537  -1.704709  ...    -1.178850     1.777472
# 2             -1   0.812780  -0.256156  ...     6.115747     9.667908
# 3             -1   1.174378   0.344640  ...     2.838853     0.499251
# 4              1  -3.172026  -3.093182  ...     0.344850     4.101145
# ...          ...        ...        ...  ...          ...          ...
# 99995          1   1.405669   0.512533  ...    -1.613148    -2.666405
# 99996          1   0.430194  -0.403471  ...     0.778653     0.750449
# 99997          1  -0.004709  -0.811126  ...     0.456345     0.543483
# 99998         -1  -3.172026  -3.093182  ...     1.556671    -1.648137
# 99999          1   2.495152   0.955959  ...     0.092483    -1.801058
#
#        feature_124  feature_125  feature_126  feature_127  feature_128  \
# 0         1.782433    14.018213     2.653056    12.600292     2.301488
# 1        -0.915458     2.831612    -1.417010     2.297459    -1.304614
# 2         5.542871    11.671595     7.281757    10.060014     6.638248
# 3         3.033732     1.513488     4.397532     1.266037     3.856384
# 4         0.614252     6.623456     0.800129     5.233243     0.362636
# ...            ...          ...          ...          ...          ...
# 99995    -1.032045    -3.289939    -1.908938    -2.608201    -1.629636
# 99996     0.376205     0.477554     0.902297     0.787591     0.857411
# 99997    -0.018550    -0.340577     0.010961    -0.252464     0.259685
# 99998     4.397054     1.772141     5.391140     0.932286     2.010078
# 99999     0.141955    -2.572515     0.136312    -1.938826     0.099691
#
#        feature_129  ts_id  y
# 0        11.445807      0  1
# 1         1.898684      1  0
# 2         9.427299      2  1
# 3         1.013469      3  0
# 4         3.926633      4  0
# ...            ...    ... ..
# 99995    -2.242429  99995  1
# 99996     0.698640  99996  0
# 99997     0.134213  99997  0
# 99998    -1.393968  99998  1
# 99999    -1.731471  99999  1
#
# [100000 rows x 139 columns]

# %%
df
# Out:
#        date     weight    resp_1    resp_2    resp_3    resp_4      resp  \
# 0         0   0.000000  0.009916  0.014079  0.008773  0.001390  0.006270
# 1         0  16.673515 -0.002828 -0.003226 -0.007319 -0.011114 -0.009792
# 2         0   0.000000  0.025134  0.027607  0.033406  0.034380  0.023970
# 3         0   0.000000 -0.004730 -0.003273 -0.000461 -0.000476 -0.003200
# 4         0   0.138531  0.001252  0.002165 -0.001215 -0.006219 -0.002604
# ...     ...        ...       ...       ...       ...       ...       ...
# 99995    16   0.000000 -0.000567 -0.001869  0.000209  0.005757  0.002378
# 99996    16   7.244412 -0.005087 -0.003462  0.003404 -0.002871 -0.007983
# 99997    16   0.742093 -0.004017 -0.005074 -0.003260  0.002065  0.000325
# 99998    16   0.223989  0.009427  0.014389  0.045104  0.055153  0.038939
# 99999    16   2.780260  0.003875  0.008955  0.014597  0.023805  0.022352
#
#        feature_0  feature_1  feature_2  ...  feature_122  feature_123  \
# 0              1  -1.872746  -2.191242  ...     1.168391     8.313583
# 1             -1  -1.349537  -1.704709  ...    -1.178850     1.777472
# 2             -1   0.812780  -0.256156  ...     6.115747     9.667908
# 3             -1   1.174378   0.344640  ...     2.838853     0.499251
# 4              1  -3.172026  -3.093182  ...     0.344850     4.101145
# ...          ...        ...        ...  ...          ...          ...
# 99995          1   1.405669   0.512533  ...    -1.613148    -2.666405
# 99996          1   0.430194  -0.403471  ...     0.778653     0.750449
# 99997          1  -0.004709  -0.811126  ...     0.456345     0.543483
# 99998         -1  -3.172026  -3.093182  ...     1.556671    -1.648137
# 99999          1   2.495152   0.955959  ...     0.092483    -1.801058
#
#        feature_124  feature_125  feature_126  feature_127  feature_128  \
# 0         1.782433    14.018213     2.653056    12.600292     2.301488
# 1        -0.915458     2.831612    -1.417010     2.297459    -1.304614
# 2         5.542871    11.671595     7.281757    10.060014     6.638248
# 3         3.033732     1.513488     4.397532     1.266037     3.856384
# 4         0.614252     6.623456     0.800129     5.233243     0.362636
# ...            ...          ...          ...          ...          ...
# 99995    -1.032045    -3.289939    -1.908938    -2.608201    -1.629636
# 99996     0.376205     0.477554     0.902297     0.787591     0.857411
# 99997    -0.018550    -0.340577     0.010961    -0.252464     0.259685
# 99998     4.397054     1.772141     5.391140     0.932286     2.010078
# 99999     0.141955    -2.572515     0.136312    -1.938826     0.099691
#
#        feature_129  ts_id  y
# 0        11.445807      0  1
# 1         1.898684      1  0
# 2         9.427299      2  1
# 3         1.013469      3  0
# 4         3.926633      4  0
# ...            ...    ... ..
# 99995    -2.242429  99995  1
# 99996     0.698640  99996  0
# 99997     0.134213  99997  0
# 99998    -1.393968  99998  1
# 99999    -1.731471  99999  1
#
# [100000 rows x 139 columns]

# %%
df.resp.plot()

# %%
df.isnull().mean()
# Out:
# date           0.00000
# weight         0.00000
# resp_1         0.00000
# resp_2         0.00000
# resp_3         0.00000
#                 ...
# feature_127    0.00283
# feature_128    0.00053
# feature_129    0.00053
# ts_id          0.00000
# y              0.00000
# Length: 139, dtype: float64

# %%
sns.distplot(df.feature_1)

# %%
sns.distplot(df.feature_2)
